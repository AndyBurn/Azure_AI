# %% [markdown]
# ### Please install the required Python modules/SDKs

# %%
# ! activate ai-azure-c1

# import sys

# sys.path.append("/opt/conda/envs/ai-azure-c1/lib/python3.8/site-packages")

# %% [markdown]
# ### This demo uses the latest pillow package to show the rectangular bounding box around the face, so please upgrade the pillow package using the command below:

# %%
# !pip install Pillow==8.4

# %% [markdown]
# ## Importing Useful Python Libraries or Packages

# %%
import io
import datetime
import pandas as pd
from PIL import Image
import requests
import io
import glob, os, sys, time, uuid

from matplotlib.pyplot import imshow
import matplotlib.pyplot as plt
# %matplotlib inline

from urllib.parse import urlparse
from io import BytesIO
from PIL import Image, ImageDraw

from video_indexer import VideoIndexer
from azure.cognitiveservices.vision.face import FaceClient
from azure.cognitiveservices.vision.face.models import TrainingStatusType
from msrest.authentication import CognitiveServicesCredentials

# %% [markdown]
# ### Documentation
# - https://docs.microsoft.com/en-us/azure/azure-video-analyzer/video-analyzer-for-media-docs/video-indexer-use-apis
#
# ### Set up the Video Analyzer Portal Login:
# - https://www.videoindexer.ai/account
# - https://www.videoindexer.ai/media/library  - All uploaded video
#
# ### Get API Subscription:
# https://api-portal.videoindexer.ai/
#
# ### Article
# - https://medium.com/microsoftazure/visual-brand-detection-with-azure-video-indexer-cd65330b908c

# %%
CONFIG = {
    'SUBSCRIPTION_KEY': '4601419f9d194c53bd1587097036aa73',
    'LOCATION': 'trial',
    'ACCOUNT_ID': '5cb4ae7e-8b31-4abc-802e-501f35f2179c'
}

video_analysis = VideoIndexer(
    vi_subscription_key=CONFIG['SUBSCRIPTION_KEY'],
    vi_location=CONFIG['LOCATION'],
    vi_account_id=CONFIG['ACCOUNT_ID']
)

# %% [markdown]
# ### Location Parameter
#  - For paid service, please use service region i.e. westus2, eastus, etc.
#  - For trial or free service, just use "trial" as I have used above.

# %%
video_analysis.check_access_token()

# %% [markdown]
# ## Note: Please upload your video to Azure Video Analyzer/Indexer service and replace the code below with your own video ID

# %% [markdown]
# ### To get video ID, check on the video in the Library and you will get the video ID, appended to the URL. An example is shown here:
# * Video URL:
# https://www.videoindexer.ai/accounts/d1629197-588b-40a7-98fa-e19785ca082e/videos/2240904ed2
# * Video ID: 2240904ed2
# * If you don't have a video at this point, you can download this video and upload it at the Video Indexer portal:
# https://github.com/udacity/cd0461-building-computer-vision-solutions-with-azure-exercises/blob/main/resources/video-indexer-demo-video.mp4

# %% [markdown]
# ## Uploading a video from local disk to Video Analyzer portal

# %% [markdown]
# If you want to upload your own video from this workspace environment to Video Analyzer portal, first upload your video to the workspace, then change the "input_filename" variable to reflect the name of your video.

# %%
uploaded_video_id = video_analysis.upload_to_video_indexer(
   input_filename='C:/Users/Gachanja/Documents/Cloud/AI Engineer Projects/Project_I/Azure_AI/material_preparation_step/30_sec_Video/Passenger_Video.mp4',
   video_name='Passenger_Video',  # unique identifier for video in Video Indexer platform
   video_language='English'
)
# Out:
# Uploading video to video indexer...

# %%
uploaded_video_id
# Out:
# 'c5097cf491'

# %%
info = video_analysis.get_video_info(uploaded_video_id, video_language='English')
# Out:
# Getting video info for: c5097cf491

# %%
info
# Out:
# {'partition': None,
#  'description': None,
#  'privacyMode': 'Private',
#  'state': 'Processed',
#  'accountId': '5cb4ae7e-8b31-4abc-802e-501f35f2179c',
#  'id': 'c5097cf491',
#  'name': 'Passenger_Video',
#  'userName': 'ODL_User 195890',
#  'created': '2022-05-19T15:14:24.7455868+00:00',
#  'isOwned': True,
#  'isEditable': True,
#  'isBase': True,
#  'durationInSeconds': 31,
#  'summarizedInsights': {'name': 'Passenger_Video',
#   'id': 'c5097cf491',
#   'privacyMode': 'Private',
#   'duration': {'time': '0:00:31.097733', 'seconds': 31.1},
#   'thumbnailVideoId': 'c5097cf491',
#   'thumbnailId': 'c66de727-60ef-4896-b625-2a20aee6122f',
#   'faces': [{'videoId': 'c5097cf491',
#     'confidence': 0,
#     'description': None,
#     'title': None,
#     'thumbnailId': '4bf756a6-5297-4882-a668-7b182907d983',
#     'seenDuration': 31.1,
#     'seenDurationRatio': 1,
#     'id': 1003,
#     'name': 'Unknown #1',
#     'appearances': [{'startTime': '0:00:00',
#       'endTime': '0:00:31.097733',
#       'startSeconds': 0,
#       'endSeconds': 31.1}]}],
#   'keywords': [],
#   'sentiments': [],
#   'emotions': [],
#   'audioEffects': [],
#   'labels': [{'id': 1,
#     'name': 'human face',
#     'appearances': [{'confidence': 0.9977,
#       'startTime': '0:00:00',
#       'endTime': '0:00:31.097733',
#       'startSeconds': 0,
#       'endSeconds': 31.1}]},
#    {'id': 2,
#     'name': 'person',
#     'appearances': [{'confidence': 0.9895,
#       'startTime': '0:00:00',
#       'endTime': '0:00:31.097733',
#       'startSeconds': 0,
#       'endSeconds': 31.1}]},
#    {'id': 3,
#     'name': 'wall',
#     'appearances': [{'confidence': 0.9818,
#       'startTime': '0:00:00',
#       'endTime': '0:00:31.097733',
#       'startSeconds': 0,
#       'endSeconds': 31.1}]},
#    {'id': 4,
#     'name': 'clothing',
#     'appearances': [{'confidence': 0.9834,
#       'startTime': '0:00:00',
#       'endTime': '0:00:31.097733',
#       'startSeconds': 0,
#       'endSeconds': 31.1}]},
#    {'id': 5,
#     'name': 'shirt',
#     'appearances': [{'confidence': 0.9814,
#       'startTime': '0:00:00',
#       'endTime': '0:00:31.097733',
#       'startSeconds': 0,
#       'endSeconds': 31.1}]},
#    {'id': 6,
#     'name': 'man',
#     'appearances': [{'confidence': 0.9528,
#       'startTime': '0:00:00',
#       'endTime': '0:00:00.0667333',
#       'startSeconds': 0,
#       'endSeconds': 0.1},
#      {'confidence': 0.9585,
#       'startTime': '0:00:06.006',
#       'endTime': '0:00:16.0827333',
#       'startSeconds': 6,
#       'endSeconds': 16.1},
#      {'confidence': 0.9621,
#       'startTime': '0:00:20.02',
#       'endTime': '0:00:31.097733',
#       'startSeconds': 20,
#       'endSeconds': 31.1}]}],
#   'framePatterns': [],
#   'brands': [],
#   'namedLocations': [],
#   'namedPeople': [],
#   'statistics': {'correspondenceCount': 0,
#    'speakerTalkToListenRatio': {},
#    'speakerLongestMonolog': {},
#    'speakerNumberOfFragments': {},
#    'speakerWordCount': {}},
#   'topics': []},
#  'videos': [{'accountId': '5cb4ae7e-8b31-4abc-802e-501f35f2179c',
#    'id': 'c5097cf491',
#    'state': 'Processed',
#    'moderationState': 'OK',
#    'reviewState': 'None',
#    'privacyMode': 'Private',
#    'processingProgress': '100%',
#    'failureCode': 'None',
#    'failureMessage': '',
#    'externalId': None,
#    'externalUrl': None,
#    'metadata': None,
#    'insights': {'version': '1.0.0.0',
#     'duration': '0:00:31.097733',
#     'sourceLanguage': 'en-US',
#     'sourceLanguages': ['en-US'],
#     'language': 'en-US',
#     'languages': ['en-US'],
#     'faces': [{'id': 1003,
#       'name': 'Unknown #1',
#       'confidence': 0,
#       'description': None,
#       'thumbnailId': '4bf756a6-5297-4882-a668-7b182907d983',
#       'title': None,
#       'imageUrl': None,
#       'thumbnails': [{'id': 'ac926867-6486-4558-b87b-347efe7baf49',
#         'fileName': 'FaceInstanceThumbnail_ac926867-6486-4558-b87b-347efe7baf49.jpg',
#         'instances': [{'adjustedStart': '0:00:00',
#           'adjustedEnd': '0:00:00.0667334',
#           'start': '0:00:00',
#           'end': '0:00:00.0667334'}]},
#        {'id': '4bf756a6-5297-4882-a668-7b182907d983',
#         'fileName': 'FaceInstanceThumbnail_4bf756a6-5297-4882-a668-7b182907d983.jpg',
#         'instances': [{'adjustedStart': '0:00:00.6006',
#           'adjustedEnd': '0:00:00.6673334',
#           'start': '0:00:00.6006',
#           'end': '0:00:00.6673334'}]},
#        {'id': '68352cfd-da4a-40dd-bc30-c87b4b717798',
#         'fileName': 'FaceInstanceThumbnail_68352cfd-da4a-40dd-bc30-c87b4b717798.jpg',
#         'instances': [{'adjustedStart': '0:00:05.005',
#           'adjustedEnd': '0:00:05.0717334',
#           'start': '0:00:05.005',
#           'end': '0:00:05.0717334'}]},
#        {'id': '25b38ba8-c7d7-4903-9608-76c1ead14460',
#         'fileName': 'FaceInstanceThumbnail_25b38ba8-c7d7-4903-9608-76c1ead14460.jpg',
#         'instances': [{'adjustedStart': '0:00:10.01',
#           'adjustedEnd': '0:00:10.0767334',
#           'start': '0:00:10.01',
#           'end': '0:00:10.0767334'}]},
#        {'id': '472cc092-07f2-4c82-8e77-2287d2f8fe5a',
#         'fileName': 'FaceInstanceThumbnail_472cc092-07f2-4c82-8e77-2287d2f8fe5a.jpg',
#         'instances': [{'adjustedStart': '0:00:15.015',
#           'adjustedEnd': '0:00:15.0817334',
#           'start': '0:00:15.015',
#           'end': '0:00:15.0817334'}]},
#        {'id': '17a8da03-8b95-4365-adc2-f9eb9d872af0',
#         'fileName': 'FaceInstanceThumbnail_17a8da03-8b95-4365-adc2-f9eb9d872af0.jpg',
#         'instances': [{'adjustedStart': '0:00:20.02',
#           'adjustedEnd': '0:00:20.0867334',
#           'start': '0:00:20.02',
#           'end': '0:00:20.0867334'}]},
#        {'id': '6be1a821-f40e-491b-a9bc-a12daa294c6e',
#         'fileName': 'FaceInstanceThumbnail_6be1a821-f40e-491b-a9bc-a12daa294c6e.jpg',
#         'instances': [{'adjustedStart': '0:00:25.025',
#           'adjustedEnd': '0:00:25.0917334',
#           'start': '0:00:25.025',
#           'end': '0:00:25.0917334'}]},
#        {'id': 'f77676b4-0232-4a1b-95ec-bda48d84c430',
#         'fileName': 'FaceInstanceThumbnail_f77676b4-0232-4a1b-95ec-bda48d84c430.jpg',
#         'instances': [{'adjustedStart': '0:00:30.03',
#           'adjustedEnd': '0:00:30.0967334',
#           'start': '0:00:30.03',
#           'end': '0:00:30.0967334'}]}],
#       'instances': [{'thumbnailsIds': ['472cc092-07f2-4c82-8e77-2287d2f8fe5a',
#          '68352cfd-da4a-40dd-bc30-c87b4b717798',
#          '25b38ba8-c7d7-4903-9608-76c1ead14460',
#          '6be1a821-f40e-491b-a9bc-a12daa294c6e',
#          'ac926867-6486-4558-b87b-347efe7baf49',
#          '4bf756a6-5297-4882-a668-7b182907d983',
#          '17a8da03-8b95-4365-adc2-f9eb9d872af0',
#          'f77676b4-0232-4a1b-95ec-bda48d84c430'],
#         'adjustedStart': '0:00:00',
#         'adjustedEnd': '0:00:31.097733',
#         'start': '0:00:00',
#         'end': '0:00:31.097733'}]}],
#     'labels': [{'id': 1,
#       'name': 'human face',
#       'language': 'en-US',
#       'instances': [{'confidence': 0.9977,
#         'adjustedStart': '0:00:00',
#         'adjustedEnd': '0:00:31.097733',
#         'start': '0:00:00',
#         'end': '0:00:31.097733'}]},
#      {'id': 2,
#       'name': 'person',
#       'referenceId': 'person',
#       'language': 'en-US',
#       'instances': [{'confidence': 0.9895,
#         'adjustedStart': '0:00:00',
#         'adjustedEnd': '0:00:31.097733',
#         'start': '0:00:00',
#         'end': '0:00:31.097733'}]},
#      {'id': 3,
#       'name': 'wall',
#       'referenceId': 'structure/wall',
#       'language': 'en-US',
#       'instances': [{'confidence': 0.9818,
#         'adjustedStart': '0:00:00',
#         'adjustedEnd': '0:00:31.097733',
#         'start': '0:00:00',
#         'end': '0:00:31.097733'}]},
#      {'id': 4,
#       'name': 'clothing',
#       'referenceId': 'consumer goods/clothing',
#       'language': 'en-US',
#       'instances': [{'confidence': 0.9834,
#         'adjustedStart': '0:00:00',
#         'adjustedEnd': '0:00:31.097733',
#         'start': '0:00:00',
#         'end': '0:00:31.097733'}]},
#      {'id': 5,
#       'name': 'shirt',
#       'referenceId': 'consumer goods/clothing/shirt',
#       'language': 'en-US',
#       'instances': [{'confidence': 0.983,
#         'adjustedStart': '0:00:00',
#         'adjustedEnd': '0:00:08.0747333',
#         'start': '0:00:00',
#         'end': '0:00:08.0747333'},
#        {'confidence': 0.979,
#         'adjustedStart': '0:00:10.01',
#         'adjustedEnd': '0:00:10.0767333',
#         'start': '0:00:10.01',
#         'end': '0:00:10.0767333'},
#        {'confidence': 0.9814,
#         'adjustedStart': '0:00:12.012',
#         'adjustedEnd': '0:00:31.097733',
#         'start': '0:00:12.012',
#         'end': '0:00:31.097733'}]},
#      {'id': 6,
#       'name': 'man',
#       'referenceId': 'person/man',
#       'language': 'en-US',
#       'instances': [{'confidence': 0.9528,
#         'adjustedStart': '0:00:00',
#         'adjustedEnd': '0:00:00.0667333',
#         'start': '0:00:00',
#         'end': '0:00:00.0667333'},
#        {'confidence': 0.9576,
#         'adjustedStart': '0:00:06.006',
#         'adjustedEnd': '0:00:08.0747333',
#         'start': '0:00:06.006',
#         'end': '0:00:08.0747333'},
#        {'confidence': 0.9574,
#         'adjustedStart': '0:00:10.01',
#         'adjustedEnd': '0:00:10.0767333',
#         'start': '0:00:10.01',
#         'end': '0:00:10.0767333'},
#        {'confidence': 0.9585,
#         'adjustedStart': '0:00:13.013',
#         'adjustedEnd': '0:00:16.0827333',
#         'start': '0:00:13.013',
#         'end': '0:00:16.0827333'},
#        {'confidence': 0.9592,
#         'adjustedStart': '0:00:20.02',
#         'adjustedEnd': '0:00:25.0917333',
#         'start': '0:00:20.02',
#         'end': '0:00:25.0917333'},
#        {'confidence': 0.9621,
#         'adjustedStart': '0:00:27.027',
#         'adjustedEnd': '0:00:31.097733',
#         'start': '0:00:27.027',
#         'end': '0:00:31.097733'}]}],
#     'scenes': [{'id': 1,
#       'instances': [{'adjustedStart': '0:00:00.3336666',
#         'adjustedEnd': '0:00:31.097733',
#         'start': '0:00:00.3336666',
#         'end': '0:00:31.097733'}]}],
#     'shots': [{'id': 1,
#       'keyFrames': [{'id': 1,
#         'instances': [{'thumbnailId': 'c84a8c8a-0a3b-4874-9572-eff16228b0ba',
#           'adjustedStart': '0:00:00.3336666',
#           'adjustedEnd': '0:00:00.4004',
#           'start': '0:00:00.3336666',
#           'end': '0:00:00.4004'}]},
#        {'id': 2,
#         'instances': [{'thumbnailId': '1df3ac97-0330-4464-be59-c9cda032f0ab',
#           'adjustedStart': '0:00:00.4004',
#           'adjustedEnd': '0:00:00.4671334',
#           'start': '0:00:00.4004',
#           'end': '0:00:00.4671334'}]}],
#       'instances': [{'adjustedStart': '0:00:00.3336666',
#         'adjustedEnd': '0:00:31.097733',
#         'start': '0:00:00.3336666',
#         'end': '0:00:31.097733'}]}],
#     'textualContentModeration': {'id': 0,
#      'bannedWordsCount': 0,
#      'bannedWordsRatio': 0,
#      'instances': []},
#     'statistics': {'correspondenceCount': 0,
#      'speakerTalkToListenRatio': {},
#      'speakerLongestMonolog': {},
#      'speakerNumberOfFragments': {},
#      'speakerWordCount': {}}},
#    'thumbnailId': 'c66de727-60ef-4896-b625-2a20aee6122f',
#    'detectSourceLanguage': False,
#    'languageAutoDetectMode': 'None',
#    'sourceLanguage': 'en-US',
#    'sourceLanguages': ['en-US'],
#    'language': 'en-US',
#    'languages': ['en-US'],
#    'indexingPreset': 'Default',
#    'linguisticModelId': '00000000-0000-0000-0000-000000000000',
#    'personModelId': '00000000-0000-0000-0000-000000000000',
#    'isAdult': False,
#    'publishedUrl': 'https://rodmandev.streaming.mediaservices.windows.net/61a9f8d9-0ab5-417b-844f-350a4a87a275/Passenger_Video.silentstream.ism/manifest(encryption=cbc)',
#    'publishedProxyUrl': None,
#    'viewToken': 'Bearer=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1cm46bWljcm9zb2Z0OmF6dXJlOm1lZGlhc2VydmljZXM6Y29udGVudGtleWlkZW50aWZpZXIiOiI1ZDZiMDIwZC01YzAzLTRmZmYtOTMyNC0wOTJkZmZhOWJhZjQiLCJuYmYiOjE2NTI5NzM4MjUsImV4cCI6MTY1MzAxNzA4NSwiaXNzIjoiaHR0cHM6Ly9icmVha2Rvd24ubWUiLCJhdWQiOiJCcmVha2Rvd25Vc2VyIn0.MmE_9LHjHAYdgzeM2VEVpa1hOCwKGlXDu7ZH2hPHSfg'}],
#  'videosRanges': [{'videoId': 'c5097cf491',
#    'range': {'start': '0:00:00', 'end': '0:00:31.097733'}}]}

# %%
video_id = 'c5097cf491'

# %%
video_analysis.get_video_info(video_id)
# Out:
# Getting video info for: c5097cf491
# {'partition': None,
#  'description': None,
#  'privacyMode': 'Private',
#  'state': 'Processed',
#  'accountId': '5cb4ae7e-8b31-4abc-802e-501f35f2179c',
#  'id': 'c5097cf491',
#  'name': 'Passenger_Video',
#  'userName': 'ODL_User 195890',
#  'created': '2022-05-19T15:14:24.7455868+00:00',
#  'isOwned': True,
#  'isEditable': True,
#  'isBase': True,
#  'durationInSeconds': 31,
#  'summarizedInsights': {'name': 'Passenger_Video',
#   'id': 'c5097cf491',
#   'privacyMode': 'Private',
#   'duration': {'time': '0:00:31.097733', 'seconds': 31.1},
#   'thumbnailVideoId': 'c5097cf491',
#   'thumbnailId': 'c66de727-60ef-4896-b625-2a20aee6122f',
#   'faces': [{'videoId': 'c5097cf491',
#     'confidence': 0,
#     'description': None,
#     'title': None,
#     'thumbnailId': '4bf756a6-5297-4882-a668-7b182907d983',
#     'seenDuration': 31.1,
#     'seenDurationRatio': 1,
#     'id': 1003,
#     'name': 'Unknown #1',
#     'appearances': [{'startTime': '0:00:00',
#       'endTime': '0:00:31.097733',
#       'startSeconds': 0,
#       'endSeconds': 31.1}]}],
#   'keywords': [],
#   'sentiments': [],
#   'emotions': [],
#   'audioEffects': [],
#   'labels': [{'id': 1,
#     'name': 'human face',
#     'appearances': [{'confidence': 0.9977,
#       'startTime': '0:00:00',
#       'endTime': '0:00:31.097733',
#       'startSeconds': 0,
#       'endSeconds': 31.1}]},
#    {'id': 2,
#     'name': 'person',
#     'appearances': [{'confidence': 0.9895,
#       'startTime': '0:00:00',
#       'endTime': '0:00:31.097733',
#       'startSeconds': 0,
#       'endSeconds': 31.1}]},
#    {'id': 3,
#     'name': 'wall',
#     'appearances': [{'confidence': 0.9818,
#       'startTime': '0:00:00',
#       'endTime': '0:00:31.097733',
#       'startSeconds': 0,
#       'endSeconds': 31.1}]},
#    {'id': 4,
#     'name': 'clothing',
#     'appearances': [{'confidence': 0.9834,
#       'startTime': '0:00:00',
#       'endTime': '0:00:31.097733',
#       'startSeconds': 0,
#       'endSeconds': 31.1}]},
#    {'id': 5,
#     'name': 'shirt',
#     'appearances': [{'confidence': 0.9814,
#       'startTime': '0:00:00',
#       'endTime': '0:00:31.097733',
#       'startSeconds': 0,
#       'endSeconds': 31.1}]},
#    {'id': 6,
#     'name': 'man',
#     'appearances': [{'confidence': 0.9528,
#       'startTime': '0:00:00',
#       'endTime': '0:00:00.0667333',
#       'startSeconds': 0,
#       'endSeconds': 0.1},
#      {'confidence': 0.9585,
#       'startTime': '0:00:06.006',
#       'endTime': '0:00:16.0827333',
#       'startSeconds': 6,
#       'endSeconds': 16.1},
#      {'confidence': 0.9621,
#       'startTime': '0:00:20.02',
#       'endTime': '0:00:31.097733',
#       'startSeconds': 20,
#       'endSeconds': 31.1}]}],
#   'framePatterns': [],
#   'brands': [],
#   'namedLocations': [],
#   'namedPeople': [],
#   'statistics': {'correspondenceCount': 0,
#    'speakerTalkToListenRatio': {},
#    'speakerLongestMonolog': {},
#    'speakerNumberOfFragments': {},
#    'speakerWordCount': {}},
#   'topics': []},
#  'videos': [{'accountId': '5cb4ae7e-8b31-4abc-802e-501f35f2179c',
#    'id': 'c5097cf491',
#    'state': 'Processed',
#    'moderationState': 'OK',
#    'reviewState': 'None',
#    'privacyMode': 'Private',
#    'processingProgress': '100%',
#    'failureCode': 'None',
#    'failureMessage': '',
#    'externalId': None,
#    'externalUrl': None,
#    'metadata': None,
#    'insights': {'version': '1.0.0.0',
#     'duration': '0:00:31.097733',
#     'sourceLanguage': 'en-US',
#     'sourceLanguages': ['en-US'],
#     'language': 'en-US',
#     'languages': ['en-US'],
#     'faces': [{'id': 1003,
#       'name': 'Unknown #1',
#       'confidence': 0,
#       'description': None,
#       'thumbnailId': '4bf756a6-5297-4882-a668-7b182907d983',
#       'title': None,
#       'imageUrl': None,
#       'thumbnails': [{'id': 'ac926867-6486-4558-b87b-347efe7baf49',
#         'fileName': 'FaceInstanceThumbnail_ac926867-6486-4558-b87b-347efe7baf49.jpg',
#         'instances': [{'adjustedStart': '0:00:00',
#           'adjustedEnd': '0:00:00.0667334',
#           'start': '0:00:00',
#           'end': '0:00:00.0667334'}]},
#        {'id': '4bf756a6-5297-4882-a668-7b182907d983',
#         'fileName': 'FaceInstanceThumbnail_4bf756a6-5297-4882-a668-7b182907d983.jpg',
#         'instances': [{'adjustedStart': '0:00:00.6006',
#           'adjustedEnd': '0:00:00.6673334',
#           'start': '0:00:00.6006',
#           'end': '0:00:00.6673334'}]},
#        {'id': '68352cfd-da4a-40dd-bc30-c87b4b717798',
#         'fileName': 'FaceInstanceThumbnail_68352cfd-da4a-40dd-bc30-c87b4b717798.jpg',
#         'instances': [{'adjustedStart': '0:00:05.005',
#           'adjustedEnd': '0:00:05.0717334',
#           'start': '0:00:05.005',
#           'end': '0:00:05.0717334'}]},
#        {'id': '25b38ba8-c7d7-4903-9608-76c1ead14460',
#         'fileName': 'FaceInstanceThumbnail_25b38ba8-c7d7-4903-9608-76c1ead14460.jpg',
#         'instances': [{'adjustedStart': '0:00:10.01',
#           'adjustedEnd': '0:00:10.0767334',
#           'start': '0:00:10.01',
#           'end': '0:00:10.0767334'}]},
#        {'id': '472cc092-07f2-4c82-8e77-2287d2f8fe5a',
#         'fileName': 'FaceInstanceThumbnail_472cc092-07f2-4c82-8e77-2287d2f8fe5a.jpg',
#         'instances': [{'adjustedStart': '0:00:15.015',
#           'adjustedEnd': '0:00:15.0817334',
#           'start': '0:00:15.015',
#           'end': '0:00:15.0817334'}]},
#        {'id': '17a8da03-8b95-4365-adc2-f9eb9d872af0',
#         'fileName': 'FaceInstanceThumbnail_17a8da03-8b95-4365-adc2-f9eb9d872af0.jpg',
#         'instances': [{'adjustedStart': '0:00:20.02',
#           'adjustedEnd': '0:00:20.0867334',
#           'start': '0:00:20.02',
#           'end': '0:00:20.0867334'}]},
#        {'id': '6be1a821-f40e-491b-a9bc-a12daa294c6e',
#         'fileName': 'FaceInstanceThumbnail_6be1a821-f40e-491b-a9bc-a12daa294c6e.jpg',
#         'instances': [{'adjustedStart': '0:00:25.025',
#           'adjustedEnd': '0:00:25.0917334',
#           'start': '0:00:25.025',
#           'end': '0:00:25.0917334'}]},
#        {'id': 'f77676b4-0232-4a1b-95ec-bda48d84c430',
#         'fileName': 'FaceInstanceThumbnail_f77676b4-0232-4a1b-95ec-bda48d84c430.jpg',
#         'instances': [{'adjustedStart': '0:00:30.03',
#           'adjustedEnd': '0:00:30.0967334',
#           'start': '0:00:30.03',
#           'end': '0:00:30.0967334'}]}],
#       'instances': [{'thumbnailsIds': ['472cc092-07f2-4c82-8e77-2287d2f8fe5a',
#          '68352cfd-da4a-40dd-bc30-c87b4b717798',
#          '25b38ba8-c7d7-4903-9608-76c1ead14460',
#          '6be1a821-f40e-491b-a9bc-a12daa294c6e',
#          'ac926867-6486-4558-b87b-347efe7baf49',
#          '4bf756a6-5297-4882-a668-7b182907d983',
#          '17a8da03-8b95-4365-adc2-f9eb9d872af0',
#          'f77676b4-0232-4a1b-95ec-bda48d84c430'],
#         'adjustedStart': '0:00:00',
#         'adjustedEnd': '0:00:31.097733',
#         'start': '0:00:00',
#         'end': '0:00:31.097733'}]}],
#     'labels': [{'id': 1,
#       'name': 'human face',
#       'language': 'en-US',
#       'instances': [{'confidence': 0.9977,
#         'adjustedStart': '0:00:00',
#         'adjustedEnd': '0:00:31.097733',
#         'start': '0:00:00',
#         'end': '0:00:31.097733'}]},
#      {'id': 2,
#       'name': 'person',
#       'referenceId': 'person',
#       'language': 'en-US',
#       'instances': [{'confidence': 0.9895,
#         'adjustedStart': '0:00:00',
#         'adjustedEnd': '0:00:31.097733',
#         'start': '0:00:00',
#         'end': '0:00:31.097733'}]},
#      {'id': 3,
#       'name': 'wall',
#       'referenceId': 'structure/wall',
#       'language': 'en-US',
#       'instances': [{'confidence': 0.9818,
#         'adjustedStart': '0:00:00',
#         'adjustedEnd': '0:00:31.097733',
#         'start': '0:00:00',
#         'end': '0:00:31.097733'}]},
#      {'id': 4,
#       'name': 'clothing',
#       'referenceId': 'consumer goods/clothing',
#       'language': 'en-US',
#       'instances': [{'confidence': 0.9834,
#         'adjustedStart': '0:00:00',
#         'adjustedEnd': '0:00:31.097733',
#         'start': '0:00:00',
#         'end': '0:00:31.097733'}]},
#      {'id': 5,
#       'name': 'shirt',
#       'referenceId': 'consumer goods/clothing/shirt',
#       'language': 'en-US',
#       'instances': [{'confidence': 0.983,
#         'adjustedStart': '0:00:00',
#         'adjustedEnd': '0:00:08.0747333',
#         'start': '0:00:00',
#         'end': '0:00:08.0747333'},
#        {'confidence': 0.979,
#         'adjustedStart': '0:00:10.01',
#         'adjustedEnd': '0:00:10.0767333',
#         'start': '0:00:10.01',
#         'end': '0:00:10.0767333'},
#        {'confidence': 0.9814,
#         'adjustedStart': '0:00:12.012',
#         'adjustedEnd': '0:00:31.097733',
#         'start': '0:00:12.012',
#         'end': '0:00:31.097733'}]},
#      {'id': 6,
#       'name': 'man',
#       'referenceId': 'person/man',
#       'language': 'en-US',
#       'instances': [{'confidence': 0.9528,
#         'adjustedStart': '0:00:00',
#         'adjustedEnd': '0:00:00.0667333',
#         'start': '0:00:00',
#         'end': '0:00:00.0667333'},
#        {'confidence': 0.9576,
#         'adjustedStart': '0:00:06.006',
#         'adjustedEnd': '0:00:08.0747333',
#         'start': '0:00:06.006',
#         'end': '0:00:08.0747333'},
#        {'confidence': 0.9574,
#         'adjustedStart': '0:00:10.01',
#         'adjustedEnd': '0:00:10.0767333',
#         'start': '0:00:10.01',
#         'end': '0:00:10.0767333'},
#        {'confidence': 0.9585,
#         'adjustedStart': '0:00:13.013',
#         'adjustedEnd': '0:00:16.0827333',
#         'start': '0:00:13.013',
#         'end': '0:00:16.0827333'},
#        {'confidence': 0.9592,
#         'adjustedStart': '0:00:20.02',
#         'adjustedEnd': '0:00:25.0917333',
#         'start': '0:00:20.02',
#         'end': '0:00:25.0917333'},
#        {'confidence': 0.9621,
#         'adjustedStart': '0:00:27.027',
#         'adjustedEnd': '0:00:31.097733',
#         'start': '0:00:27.027',
#         'end': '0:00:31.097733'}]}],
#     'scenes': [{'id': 1,
#       'instances': [{'adjustedStart': '0:00:00.3336666',
#         'adjustedEnd': '0:00:31.097733',
#         'start': '0:00:00.3336666',
#         'end': '0:00:31.097733'}]}],
#     'shots': [{'id': 1,
#       'keyFrames': [{'id': 1,
#         'instances': [{'thumbnailId': 'c84a8c8a-0a3b-4874-9572-eff16228b0ba',
#           'adjustedStart': '0:00:00.3336666',
#           'adjustedEnd': '0:00:00.4004',
#           'start': '0:00:00.3336666',
#           'end': '0:00:00.4004'}]},
#        {'id': 2,
#         'instances': [{'thumbnailId': '1df3ac97-0330-4464-be59-c9cda032f0ab',
#           'adjustedStart': '0:00:00.4004',
#           'adjustedEnd': '0:00:00.4671334',
#           'start': '0:00:00.4004',
#           'end': '0:00:00.4671334'}]}],
#       'instances': [{'adjustedStart': '0:00:00.3336666',
#         'adjustedEnd': '0:00:31.097733',
#         'start': '0:00:00.3336666',
#         'end': '0:00:31.097733'}]}],
#     'textualContentModeration': {'id': 0,
#      'bannedWordsCount': 0,
#      'bannedWordsRatio': 0,
#      'instances': []},
#     'statistics': {'correspondenceCount': 0,
#      'speakerTalkToListenRatio': {},
#      'speakerLongestMonolog': {},
#      'speakerNumberOfFragments': {},
#      'speakerWordCount': {}}},
#    'thumbnailId': 'c66de727-60ef-4896-b625-2a20aee6122f',
#    'detectSourceLanguage': False,
#    'languageAutoDetectMode': 'None',
#    'sourceLanguage': 'en-US',
#    'sourceLanguages': ['en-US'],
#    'language': 'en-US',
#    'languages': ['en-US'],
#    'indexingPreset': 'Default',
#    'linguisticModelId': '00000000-0000-0000-0000-000000000000',
#    'personModelId': '00000000-0000-0000-0000-000000000000',
#    'isAdult': False,
#    'publishedUrl': 'https://rodmandev.streaming.mediaservices.windows.net/61a9f8d9-0ab5-417b-844f-350a4a87a275/Passenger_Video.silentstream.ism/manifest(encryption=cbc)',
#    'publishedProxyUrl': None,
#    'viewToken': 'Bearer=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1cm46bWljcm9zb2Z0OmF6dXJlOm1lZGlhc2VydmljZXM6Y29udGVudGtleWlkZW50aWZpZXIiOiI1ZDZiMDIwZC01YzAzLTRmZmYtOTMyNC0wOTJkZmZhOWJhZjQiLCJuYmYiOjE2NTI5NzM4OTEsImV4cCI6MTY1MzAxNzE1MSwiaXNzIjoiaHR0cHM6Ly9icmVha2Rvd24ubWUiLCJhdWQiOiJCcmVha2Rvd25Vc2VyIn0.3D_0w2q2HXeJIkhuT8oiaJUkxgPC8rb2Oolcf95vRu4'}],
#  'videosRanges': [{'videoId': 'c5097cf491',
#    'range': {'start': '0:00:00', 'end': '0:00:31.097733'}}]}

# %%
info = video_analysis.get_video_info(video_id, video_language='English')
# Out:
# Getting video info for: c5097cf491

# %% [markdown]
# ## Processing RAW Json
# ### Getting a list of thumbnails where we find human face

# %%
if len(info['videos'][0]['insights']['faces'][0]['thumbnails']):
    print("We found {} faces in this video.".format(str(len(info['videos'][0]['insights']['faces'][0]['thumbnails']))))
# Out:
# We found 8 faces in this video.

# %%
info['videos'][0]['insights']['faces'][0]['thumbnails']
# Out:
# [{'id': 'ac926867-6486-4558-b87b-347efe7baf49',
#   'fileName': 'FaceInstanceThumbnail_ac926867-6486-4558-b87b-347efe7baf49.jpg',
#   'instances': [{'adjustedStart': '0:00:00',
#     'adjustedEnd': '0:00:00.0667334',
#     'start': '0:00:00',
#     'end': '0:00:00.0667334'}]},
#  {'id': '4bf756a6-5297-4882-a668-7b182907d983',
#   'fileName': 'FaceInstanceThumbnail_4bf756a6-5297-4882-a668-7b182907d983.jpg',
#   'instances': [{'adjustedStart': '0:00:00.6006',
#     'adjustedEnd': '0:00:00.6673334',
#     'start': '0:00:00.6006',
#     'end': '0:00:00.6673334'}]},
#  {'id': '68352cfd-da4a-40dd-bc30-c87b4b717798',
#   'fileName': 'FaceInstanceThumbnail_68352cfd-da4a-40dd-bc30-c87b4b717798.jpg',
#   'instances': [{'adjustedStart': '0:00:05.005',
#     'adjustedEnd': '0:00:05.0717334',
#     'start': '0:00:05.005',
#     'end': '0:00:05.0717334'}]},
#  {'id': '25b38ba8-c7d7-4903-9608-76c1ead14460',
#   'fileName': 'FaceInstanceThumbnail_25b38ba8-c7d7-4903-9608-76c1ead14460.jpg',
#   'instances': [{'adjustedStart': '0:00:10.01',
#     'adjustedEnd': '0:00:10.0767334',
#     'start': '0:00:10.01',
#     'end': '0:00:10.0767334'}]},
#  {'id': '472cc092-07f2-4c82-8e77-2287d2f8fe5a',
#   'fileName': 'FaceInstanceThumbnail_472cc092-07f2-4c82-8e77-2287d2f8fe5a.jpg',
#   'instances': [{'adjustedStart': '0:00:15.015',
#     'adjustedEnd': '0:00:15.0817334',
#     'start': '0:00:15.015',
#     'end': '0:00:15.0817334'}]},
#  {'id': '17a8da03-8b95-4365-adc2-f9eb9d872af0',
#   'fileName': 'FaceInstanceThumbnail_17a8da03-8b95-4365-adc2-f9eb9d872af0.jpg',
#   'instances': [{'adjustedStart': '0:00:20.02',
#     'adjustedEnd': '0:00:20.0867334',
#     'start': '0:00:20.02',
#     'end': '0:00:20.0867334'}]},
#  {'id': '6be1a821-f40e-491b-a9bc-a12daa294c6e',
#   'fileName': 'FaceInstanceThumbnail_6be1a821-f40e-491b-a9bc-a12daa294c6e.jpg',
#   'instances': [{'adjustedStart': '0:00:25.025',
#     'adjustedEnd': '0:00:25.0917334',
#     'start': '0:00:25.025',
#     'end': '0:00:25.0917334'}]},
#  {'id': 'f77676b4-0232-4a1b-95ec-bda48d84c430',
#   'fileName': 'FaceInstanceThumbnail_f77676b4-0232-4a1b-95ec-bda48d84c430.jpg',
#   'instances': [{'adjustedStart': '0:00:30.03',
#     'adjustedEnd': '0:00:30.0967334',
#     'start': '0:00:30.03',
#     'end': '0:00:30.0967334'}]}]

# %% [markdown]
# ## Getting Thumbnail ID from the Analysis JSON

# %%
images = []
img_raw = []
img_strs = []
for each_thumb in info['videos'][0]['insights']['faces'][0]['thumbnails']:
    if 'fileName' in each_thumb and 'id' in each_thumb:
        file_name = each_thumb['fileName']
        thumb_id = each_thumb['id']
        img_code = video_analysis.get_thumbnail_from_video_indexer(video_id,  thumb_id)
        img_strs.append(img_code)
        img_stream = io.BytesIO(img_code)
        img_raw.append(img_stream)
        img = Image.open(img_stream)
        images.append(img)
# Out:
# Getting thumbnail from video: c5097cf491, thumbnail: ac926867-6486-4558-b87b-347efe7baf49
# Getting thumbnail from video: c5097cf491, thumbnail: 4bf756a6-5297-4882-a668-7b182907d983
# Getting thumbnail from video: c5097cf491, thumbnail: 68352cfd-da4a-40dd-bc30-c87b4b717798
# Getting thumbnail from video: c5097cf491, thumbnail: 25b38ba8-c7d7-4903-9608-76c1ead14460
# Getting thumbnail from video: c5097cf491, thumbnail: 472cc092-07f2-4c82-8e77-2287d2f8fe5a
# Getting thumbnail from video: c5097cf491, thumbnail: 17a8da03-8b95-4365-adc2-f9eb9d872af0
# Getting thumbnail from video: c5097cf491, thumbnail: 6be1a821-f40e-491b-a9bc-a12daa294c6e
# Getting thumbnail from video: c5097cf491, thumbnail: f77676b4-0232-4a1b-95ec-bda48d84c430

# %% [markdown]
# ## Now, let's view the face-specific thumbnails

# %%
for img in images:
    print(img.info)
    plt.figure()
    plt.imshow(img)
# Out:
# {'comment': b'Lavc58.54.100\x00'}
# {'comment': b'Lavc58.54.100\x00'}
# {'comment': b'Lavc58.54.100\x00'}
# {'comment': b'Lavc58.54.100\x00'}
# {'comment': b'Lavc58.54.100\x00'}
# {'comment': b'Lavc58.54.100\x00'}
# {'comment': b'Lavc58.54.100\x00'}
# {'comment': b'Lavc58.54.100\x00'}

# %% [markdown]
# ## Let's extract and save these face thumbnails to the local disk
# - Download from Cloud

# %%
i = 1
for img in images:
    print(type(img))
    img.save('human-face' + str(i) + '.jpg')
    i= i+ 1
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# <class 'PIL.JpegImagePlugin.JpegImageFile'>

# %% [markdown]
# ## Verify the download process

# %%
# !dir human-face*.jpg
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is C41D-D1C3
#
#  Directory of C:\Users\Gachanja\Documents\Cloud\AI Engineer Projects\Project_I\Azure_AI\step_3\Video_Indexing\Notebooks
#
# 05/19/2022  06:36 PM            12,114 human-face1.jpg
# 05/19/2022  06:36 PM            11,868 human-face2.jpg
# 05/19/2022  06:36 PM            11,446 human-face3.jpg
# 05/19/2022  06:36 PM            12,537 human-face4.jpg
# 05/19/2022  06:36 PM            11,994 human-face5.jpg
# 05/19/2022  06:36 PM            11,775 human-face6.jpg
# 05/19/2022  06:36 PM            12,104 human-face7.jpg
# 05/19/2022  06:36 PM            12,664 human-face8.jpg
#                8 File(s)         96,502 bytes
#                0 Dir(s)     247,447,552 bytes free

# %% [markdown]
# ## Getting thumbnail from the SDK

# %%
# Enter one of the thumbnail output you got from the previous cell, 
# under the "Getting Thumbnail ID from the Analysis JSON" section.
thumbnail_id='ac926867-6486-4558-b87b-347efe7baf49'

# %%
img_code = video_analysis.get_thumbnail_from_video_indexer(video_id,  thumbnail_id)
print(img_code)
# Out:
# Getting thumbnail from video: c5097cf491, thumbnail: ac926867-6486-4558-b87b-347efe7baf49
# b'\xff\xd8\xff\xfe\x00\x10Lavc58.54.100\x00\xff\xdb\x00C\x00\x08\x04\x04\x04\x04\x04\x05\x05\x05\x05\x05\x05\x06\x06\x06\x06\x06\x06\x06\x06\x06\x06\x06\x06\x06\x07\x07\x07\x08\x08\x08\x07\x07\x07\x06\x06\x07\x07\x08\x08\x08\x08\t\t\t\x08\x08\x08\x08\t\t\n\n\n!1\x12A\x05Q\x132aq\x81\x91"\x06\xa1\xc1\xb1B\x14\xd1\x07#3rR\xf0b\x83\x92\x15\x82SCs\xe1\xc24\xb25\xf1\xa26$tc%\x11\x01\x01\x00\x02\x02\x03\x00\x02\x01\x05\x00\x03\x01\x01\x00\x00\x00\x01\x02\x11!1\x12A\x03\x812Q\xb1aqB"\xd1\xc1\xf0\x13\x04\xff\xc0\x00\x11\x08\x022\x01\x8c\x03\x01"\x00\x02\x11\x00\x03\x11\x00\xff\xda\x00\x0c\x03\x01\x00\x02\x11\x03\x11\x00?\x00\xfa\xa6"\x94[\x1f\x96ve\x00\xd1~U\x8d`&]\x9e;d\x81\x9by\x00\xb0\x10\xd6\x98\xa5c\xe56\xf2(<\x94\x06<\xa2q\xd8\xe8XP\xde$\x07#\x8b\xf0\x12\x84\x9fC\xaf\xc9CXb\x80\xe4\xf2\xb2.1b\xe4gc\x8a"p@\xd6\xdc\xdc\xac\xaf-\x9a8S\x1aAd\x92q\xc3%\x86o\x82\x14\xb4\xd9\x1fC\xa6\x1b&\x12\xe0L\xbbW2\xc4\xd7\x10x\xbdf\xbcA\x90c\xe5\x0f\xcb4\n\x03>J\x07\xc0\xb6C\x02D1\x13 1\r\x88\x80d\x94\xc9\x00b\x1b\x10\x00\x86 \x1a\x07\xc0\x10>\x00!1\xb2\x18\xab\x0cLHl\x82X\x03\x00\x941\r\x88\xb0\x02c\x13\x00E\x12\x91D\xa0d\x94\xc9\x03\xdaHt\x80\x0e\x88(i\t\x14\x004\x90 \x01=\x98\r\x88\x01\x82\x00\x15*\x84\xe8HL@H\x866\x0c,\xe9,Cb\n\x04\xde\xe3\xb2lT\xc8\x9b\x10I\x92\xd9\t\xd1\xd86+\x06\xc2\x93d\xb1\xb6&\x04\x80\x01(LC\x97\x02@b\x00%\x03\x10\xc4\x02\x1a\x10\xd0\x000&L\x04\xc5@\x1c\xc0\x14\x0c,LivL\x06\xc4D\x0cCb\t@\x03\x11b\xc3\x01\x08\x946\xc4\x0cV\x07\xba\xc4>\x827\x12\x9a)2\x06\x8a\x8d,VM\xa1s\r\x91vKb\xe6\x06\xc3[\x16>b\x1b\x10F\x9c\xc2l\x94\xc5.f\r\x0b\xbf\xb4M\xd1;\xa0\xb2d@\xdd\x8bq!\x91I\x93{\x95"\x1d\x96R\x9bd\x80\x12\xa4\x02\x1b\x11\x14\x00\x00\t\x92S$\x01\x92S$\xa0\x06\x00\xc9B\x06\x00\xc0HbC\x016K)\xa2\x18\x12\x08\x01\x00\xc0\x04\x00\x02\xea\x04\xa0b\x1b\x10\x03\x10\xc4\xcb\t\xd1\x81 \x14\xd8\x80\x00\xf6\xd3\x06\xc4\x81\xb2\xa2\x93\x1d\x90\x989m\xc4\nobl\x9b\xbe\xa5&YEZBr\xb0\x05E\xd9\xa0\x1b\x03b\xb0\x87\xb0&"^\xc09$H\xecRv\x80\x1f\x02\x1b\x18\x994\xa9a\xd0\x18\xfa\r\x08\x90 b\x17\x93F\x00\xc9&\x85\x08B \xab\x13`\x84\xc4\t\xb0\xb1\x05\x94;\x13blVJ\x13b)\x8a\xc0\x10\t\xb0\xb0\x1b!\x8d\xb2P\xaa\x10\xc0L\x86\x89\x85\x82\xdd\x89\x97\xdaQ`\t\x00@\xc9)\x92C`bC,X\x18\xa8lD\xa9@\x00\x01\xec[\x0b\xb0\xb1\x1aS\xb17`\'\xb0J\x11V@\xc1\xb5X&K\x04kK\xb56\t\x92\x16\x82V\x89\x84\x88Lm\xecL\x96tR$l\x92\x00LlL\xab\xa4\xf5\x18\x98\x99*(\x96\x00M\x84\x02d\xdb(\xb1X\xad\xfa\x88\xc9\x9f\x16;\xe7\x9cUq\xddl(\xbb$\xe5\xc9\xdf{D6z\xdc\x17\xfc\xc8K\xbdv\xb9/\x93[\xa7~\x0b\x9e7\xf8\x93C\xa9\x88\x8c\x1a\x9cZ\xa8\xb9b\xcb\x8b"\\\\g\x19W\xc1\x96\xc0,\x86\xc6*\xdc\x06\x98\xecT \x1bd\xb614\x01{\n\xc7\xd0\x9b\x0b\x05\x85\x85\x82d\x05\x89\xf1\x18\x99JCb\x04\x13@(aCF\x8a\x846\x85CF\x83\x10\xe8(\x04\x03hB\x11\xec\x05\x89\x0e\x8a\x0b%\x94&\n@&!;M*\xc3\x98\x90E\xcb\xb5\x8a\xb0\x10\x08)0b@\xc9BlI\x83\x13\x01\xd8\xa4\xc5b\x93\x00\x02y\x9d\x8d6\xdd/\xd4\x03\x03\xca\xee\xbfV\xf6\x9e\xd59C\xcc\xfd#,\x7f\xdd\xc3\xf5\xf8\x1f-\xde\xbe\xb2\xee\x9d\xcaN1\xc8\xf4\xd8\xbaG\x1b\xa7^\r\xd1p\xc2\xe5R\xdd>\xaf\xb8}I\xd9{|\xa7\x0c\xba\xb89\xc6\xee0R\x95m\xc1\xd2\xe2x\xbd\xc3\xf6\x82\xfee\xa1\xd3\xa8\xdd\xaf3/\xb7\x8a\x8d:\xf7\xb6|\xbc\xa7v\xf7\xb7\xc5\xbd\xec\xceR\x92|M\xcf\x94\x9e\xf6v\xf4\xb5?RwmfN|\xba\xbc\xa9\xf8Br\x8a_\x03\x9b>\xb7.Z\xf3u\x19\xb2x\xc6Y&\xef\xe2\xeb\xec9<\xceR\';\xbf\x11\xbf\x1e\x8b\x1d\x13\xd4\xdfB\x7fJ\xf6\x1c\xd2\xc9$\x85\xcf\xcdE\x993q\xddwa\xd7\xe5\xc5~^L\x98\xefg\xc9\'\x14\xfd\xa7\xa3\xdb>\xb2\xee}\xba\xa1\xcd\rF>\x90\x9ar\x9a\xf6K\xa7\xb4\xf0\xa2\xf6\x13\x97+L[\x86ST\xf1\xaf\xbd\xd0\xfds\xda5)y\xdef\x9a\x7f\x9a..K\xdc\xfa\x9e\xae\x93[\xa4\xd7C\xcc\xd3\xe6\x86X\xff\x00\x85\xa7^\xd3\xf3Hd\xe7]=f\xfaMn\xabG5\x93M\x96xd\xb6\xb8I\xc6\xd ...

# %% [markdown]
# ## Converting encoded image to visible image

# %%
img_code = video_analysis.get_thumbnail_from_video_indexer(video_id,  thumbnail_id)
img_stream = io.BytesIO(img_code)
img = Image.open(img_stream)
imshow(img)
# Out:
# Getting thumbnail from video: c5097cf491, thumbnail: ac926867-6486-4558-b87b-347efe7baf49

# %% [markdown]
# ## Getting thumbnails using Keyframes

# %%
keyframes = []
for shot in info["videos"][0]["insights"]["shots"]:
    for keyframe in shot["keyFrames"]:
        keyframes.append(keyframe["instances"][0]['thumbnailId'])

# %%
for keyframe in keyframes:
    img_str = video_analysis.get_thumbnail_from_video_indexer(video_id,  keyframe)
# Out:
# Getting thumbnail from video: c5097cf491, thumbnail: c84a8c8a-0a3b-4874-9572-eff16228b0ba
# Getting thumbnail from video: c5097cf491, thumbnail: 1df3ac97-0330-4464-be59-c9cda032f0ab

# %% [markdown]
# ## Emotion from the Video Analyzer

# %%
info['summarizedInsights']['sentiments']
# Out:
# []

# %%
info['summarizedInsights']['emotions']
# Out:
# []

# %% [markdown]
# # Collecting Faces from  Video Analyzer

# %%
PASSENGER_FACE_KEY = "c7bd0eb4d4bb44e289c26170f18c16a3"
PASSENGER_FACE_ENDPOINT = "https://videoanalyzer.cognitiveservices.azure.com/"

# %%
# Create a client
face_client = FaceClient(PASSENGER_FACE_ENDPOINT, CognitiveServicesCredentials(PASSENGER_FACE_KEY))

# %%
face_client.api_version
# Out:
# '1.0'

# %% [markdown]
# https://github.com/Azure-Samples/cognitive-services-quickstart-code/blob/master/python/Face/DetectIdentifyFace.py

# %% [markdown]
# # Creating Person Model Based on Faces in the Video
# ### We have already downloaded and saved the face thumbnails in the previous steps
# - We will be using those face thumbnails here to build the Person model

# %%
PERSON_GROUP_ID = str(uuid.uuid4())
person_group_name = 'alex_gachanja'

# Note if this UUID already used earlier, you will get an error

# %%
## This code is taken from Azure Face SDK 
## ---------------------------------------
def build_person_group(client, person_group_id, pgp_name):
    print('Create and build a person group...')
    # Create empty Person Group. Person Group ID must be lower case, alphanumeric, and/or with '-', '_'.
    print('Person group ID:', person_group_id)
    client.person_group.create(person_group_id = person_group_id, name=person_group_id)

    # Create a person group person.
    human_person = client.person_group_person.create(person_group_id, pgp_name)
    # Find all jpeg human images in working directory.
    human_face_images = [file for file in glob.glob('*.jpg') if file.startswith("human-face")]
    # Add images to a Person object
    for image_p in human_face_images:
        with open(image_p, 'rb') as w:
            client.person_group_person.add_face_from_stream(person_group_id, human_person.person_id, w)

    # Train the person group, after a Person object with many images were added to it.
    client.person_group.train(person_group_id)

    # Wait for training to finish.
    while (True):
        training_status = client.person_group.get_training_status(person_group_id)
        print("Training status: {}.".format(training_status.status))
        if (training_status.status is TrainingStatusType.succeeded):
            break
        elif (training_status.status is TrainingStatusType.failed):
            client.person_group.delete(person_group_id=PERSON_GROUP_ID)
            sys.exit('Training the person group has failed.')
        time.sleep(5)

# %%
build_person_group(face_client, PERSON_GROUP_ID, person_group_name)
# Out:
# Create and build a person group...
# Person group ID: 1e176096-24c1-4a6e-a4bd-86807376ccb9
# Training status: running.
# Training status: succeeded.

# %% [markdown]
# # Making sure the Person model has faces and they all belong to the same person

# %%
'''
Detect all faces in query image list, then add their face IDs to a new list.
'''
def detect_faces(client, query_images_list):
    print('Detecting faces in query images list...')

    face_ids = {} # Keep track of the image ID and the related image in a dictionary
    for image_name in query_images_list:
        image = open(image_name, 'rb') # BufferedReader
        print("Opening image: ", image.name)
        time.sleep(5)

        # Detect the faces in the query images list one at a time, returns list[DetectedFace]
        faces = client.face.detect_with_stream(image)  

        # Add all detected face IDs to a list
        for face in faces:
            print('Face ID', face.face_id, 'found in image', os.path.splitext(image.name)[0]+'.jpg')
            # Add the ID to a dictionary with image name as a key.
            # This assumes there is only one face per image (since you can't have duplicate keys)
            face_ids[image.name] = face.face_id

    return face_ids

# %%
test_images = [file for file in glob.glob('*.jpg') if file.startswith("human-face")]

# %%
test_images
# Out:
# ['human-face1.jpg',
#  'human-face2.jpg',
#  'human-face3.jpg',
#  'human-face4.jpg',
#  'human-face5.jpg',
#  'human-face6.jpg',
#  'human-face7.jpg',
#  'human-face8.jpg']

# %%
ids = detect_faces(face_client, test_images)
# Out:
# Detecting faces in query images list...
# Opening image:  human-face1.jpg
# Face ID cd15892e-6209-4c8c-8de2-3dab15efb701 found in image human-face1.jpg
# Opening image:  human-face2.jpg
# Face ID 810ba7b4-85d4-4cdc-88f7-b420b4f0a942 found in image human-face2.jpg
# Opening image:  human-face3.jpg
# Face ID aaa23cc8-5bec-4757-ba94-7a4fca1ff8c4 found in image human-face3.jpg
# Opening image:  human-face4.jpg
# Face ID 2421667f-45ee-4882-933f-764bf9ecd8c8 found in image human-face4.jpg
# Opening image:  human-face5.jpg
# Face ID 423207a8-7c67-4d1d-840d-e57e1b58a702 found in image human-face5.jpg
# Opening image:  human-face6.jpg
# Face ID 26d75af0-cad6-42d3-b66e-21b134b006bf found in image human-face6.jpg
# Opening image:  human-face7.jpg
# Face ID 3682c5f1-6844-4a3f-9ccb-c7f59d320776 found in image human-face7.jpg
# Opening image:  human-face8.jpg
# Face ID 661f69f0-6bd9-4beb-9feb-bc98c3967072 found in image human-face8.jpg

# %%
ids
# Out:
# {'human-face1.jpg': 'cd15892e-6209-4c8c-8de2-3dab15efb701',
#  'human-face2.jpg': '810ba7b4-85d4-4cdc-88f7-b420b4f0a942',
#  'human-face3.jpg': 'aaa23cc8-5bec-4757-ba94-7a4fca1ff8c4',
#  'human-face4.jpg': '2421667f-45ee-4882-933f-764bf9ecd8c8',
#  'human-face5.jpg': '423207a8-7c67-4d1d-840d-e57e1b58a702',
#  'human-face6.jpg': '26d75af0-cad6-42d3-b66e-21b134b006bf',
#  'human-face7.jpg': '3682c5f1-6844-4a3f-9ccb-c7f59d320776',
#  'human-face8.jpg': '661f69f0-6bd9-4beb-9feb-bc98c3967072'}

# %% [markdown]
# ### Verifying that 2 random images from the list belong to the same person
# - #### Note: So far we have not used the face recognition part, only face detection.

# %%
# Verification example for faces of the same person.
verify_result = face_client.face.verify_face_to_face(ids['human-face1.jpg'], ids['human-face2.jpg'])

# %%
if verify_result.is_identical:
    print("Faces are of the same (Positive) person, similarity confidence: {}.".format(verify_result.confidence))
else:
    print("Faces are of different (Negative) persons, similarity confidence: {}.".format(verify_result.confidence))
# Out:
# Faces are of the same (Positive) person, similarity confidence: 0.89174.

# %% [markdown]
# ## Matching face from ID card with face from Video Analyzer

# %%
def show_image_in_cell(face_url):
    response = requests.get(face_url)
    img = Image.open(BytesIO(response.content))
    plt.figure(figsize=(10,5))
    plt.imshow(img)
    plt.show()

# %%
dl_source_url = 'https://raw.githubusercontent.com/AndyBurn/Azure_AI/main/material_preparation_step/Digital_IDs/Alex_Gachanja_ID-01.png'

# %%
show_image_in_cell(dl_source_url)

# %%
## -------
## Reading file locally
## -------
# If I had image file locally, I would have used the following method
# dl_image = open('C:/Users/Gachanja/Documents/Cloud/AI Engineer Projects/Project_I/Azure_AI/material_preparation_step/Digital_IDs/Alex_Gachanja_ID-01', 'rb')
# dl_faces = face_client.face.detect_with_stream(dl_image)

# %%
dl_faces = face_client.face.detect_with_url(dl_source_url)

# %% [markdown]
# ## Viewing Face ID and then saving it into the list of already saved Face IDs

# %%
for face in dl_faces:
    print('Face ID', face.face_id, 'found in image', dl_source_url)
    # Add the ID to a dictionary with image name as a key.
    # This assumes there is only one face per image (since you can't have duplicate keys)
    ids['Alex_Gachanja_ID-01.png'] = face.face_id
# Out:
# Face ID db76546d-5139-4774-b004-5f0913d9b4fd found in image https://raw.githubusercontent.com/AndyBurn/Azure_AI/main/material_preparation_step/Digital_IDs/Alex_Gachanja_ID-01.png

# %%
ids

# %% [markdown]
# ## Perform face verification between the Face ID from the identity card and one of the Face IDs from the video

# %%
# Verification example for faces of the same person.
dl_verify_result = face_client.face.verify_face_to_face(ids['human-face4.jpg'], ids['Alex_Gachanja_ID-01.png'])

# %%
if dl_verify_result.is_identical:
    print("Faces are of the same (Positive) person, similarity confidence: {}.".format(dl_verify_result.confidence))
else:
    print("Faces are of different (Negative) persons, similarity confidence: {}.".format(dl_verify_result.confidence))
# Out:
# Faces are of the same (Positive) person, similarity confidence: 0.77128.

# %%
ids['Alex_Gachanja_ID-01.png']
# Out:
# 'db76546d-5139-4774-b004-5f0913d9b4fd'

# %%
ids.values()
# Out:
# dict_values(['cd15892e-6209-4c8c-8de2-3dab15efb701', '810ba7b4-85d4-4cdc-88f7-b420b4f0a942', 'aaa23cc8-5bec-4757-ba94-7a4fca1ff8c4', '2421667f-45ee-4882-933f-764bf9ecd8c8', '423207a8-7c67-4d1d-840d-e57e1b58a702', '26d75af0-cad6-42d3-b66e-21b134b006bf', '3682c5f1-6844-4a3f-9ccb-c7f59d320776', '661f69f0-6bd9-4beb-9feb-bc98c3967072', 'db76546d-5139-4774-b004-5f0913d9b4fd'])

# %%
dl_faces[0].face_rectangle.as_dict()
# Out:
# {'width': 145, 'height': 145, 'left': 118, 'top': 194}

# %%
# TAKEN FROM THE Azure SDK Sample
# Convert width height to a point in a rectangle
def getRectangle(faceDictionary):
    rect = faceDictionary.face_rectangle
    left = rect.left
    top = rect.top
    right = left + rect.width
    bottom = top + rect.height
    
    return ((left, top), (right, bottom))

# %%
def drawFaceRectangles(source_file, detected_face_object) :
    # Download the image from the url
    response = requests.get(source_file)
    img = Image.open(BytesIO(response.content))
    # Draw a red box around every detected faces
    draw = ImageDraw.Draw(img)
    for face in detected_face_object:
        draw.rectangle(getRectangle(face), outline='red', width = 5)
    return img

# %%
drawFaceRectangles(dl_source_url, dl_faces)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1057x647 at 0x2C36903EBC8>

# %% [markdown]
# ## Matching Face ID from the identity card with Video Analyzer Person Model

# %%
# A list of Face ID
ids
# Out:
# {'human-face1.jpg': 'cd15892e-6209-4c8c-8de2-3dab15efb701',
#  'human-face2.jpg': '810ba7b4-85d4-4cdc-88f7-b420b4f0a942',
#  'human-face3.jpg': 'aaa23cc8-5bec-4757-ba94-7a4fca1ff8c4',
#  'human-face4.jpg': '2421667f-45ee-4882-933f-764bf9ecd8c8',
#  'human-face5.jpg': '423207a8-7c67-4d1d-840d-e57e1b58a702',
#  'human-face6.jpg': '26d75af0-cad6-42d3-b66e-21b134b006bf',
#  'human-face7.jpg': '3682c5f1-6844-4a3f-9ccb-c7f59d320776',
#  'human-face8.jpg': '661f69f0-6bd9-4beb-9feb-bc98c3967072',
#  'Alex_Gachanja_ID-01.png': 'db76546d-5139-4774-b004-5f0913d9b4fd'}

# %% [markdown]
# ## Using the face ID from the identify card and matching the identity with the Person Group model

# %%
# Enter the face ID of ca-dl-sample.png from the output of the cell above
get_the_face_id_from_the_driving_license = 'db76546d-5139-4774-b004-5f0913d9b4fd'

# %%
person_gp_results = face_client.face.identify([get_the_face_id_from_the_driving_license], PERSON_GROUP_ID)

# %%
for result in person_gp_results:
    for candidate in result.candidates:
        print("The Identity match confidence is {}".format(candidate.confidence))
# Out:
# The Identity match confidence is 0.78749
